# %% [markdown]
# # Breast Cancer Survival Analysis - Black Patients
#
# This notebook analyzes breast cancer survival data with a focus on racial disparities, particularly for Black patients.

# %% [markdown]
# ## Setup and Import Libraries

# %%
# Install required packages if needed
# !pip install pandas numpy matplotlib seaborn lifelines scipy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from lifelines import KaplanMeierFitter, CoxPHFitter
from lifelines.statistics import logrank_test
from scipy.stats import ttest_ind, chi2_contingency
import warnings

warnings.filterwarnings("ignore")

# Set the style for visualizations
plt.style.use("seaborn-v0_8-whitegrid")
sns.set_palette("deep")
sns.set_context("notebook")

# %% [markdown]
# ## Data Loading and Exploration

# %%
# Load the data
file_path = "data1.csv"
df = pd.read_csv(file_path)
print(f"Dataset loaded with {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# Dataset loaded with 1084 rows and 63 columns

# %%
# Display the first few rows
df.head()
# Out:
#                        Study ID    Patient ID        Sample ID  Diagnosis Age  \
# 0  brca_tcga_pan_can_atlas_2018  TCGA-3C-AAAU  TCGA-3C-AAAU-01             55
# 1  brca_tcga_pan_can_atlas_2018  TCGA-3C-AALI  TCGA-3C-AALI-01             50
# 2  brca_tcga_pan_can_atlas_2018  TCGA-3C-AALJ  TCGA-3C-AALJ-01             62
# 3  brca_tcga_pan_can_atlas_2018  TCGA-3C-AALK  TCGA-3C-AALK-01             52
# 4  brca_tcga_pan_can_atlas_2018  TCGA-4H-AAAK  TCGA-4H-AAAK-01             50
#
#   Neoplasm Disease Stage American Joint Committee on Cancer Code  \
# 0                                            STAGE X
# 1                                          STAGE IIB
# 2                                          STAGE IIB
# 3                                           STAGE IA
# 4                                         STAGE IIIA
#
#   American Joint Committee on Cancer Publication Version Type  \
# 0                                                6TH
# 1                                                6TH
# 2                                                7TH
# 3                                                7TH
# 4                                                7TH
#
#    Aneuploidy Score  Buffa Hypoxia Score    Cancer Type  \
# 0              19.0                -21.0  Breast Cancer
# 1              22.0                  5.0  Breast Cancer
# 2              13.0                 -5.0  Breast Cancer
# 3               4.0                -27.0  Breast Cancer
# 4               7.0                -27.0  Breast Cancer
#
#   TCGA PanCanAtlas Cancer Type Acronym  ... Tumor Break Load  \
# 0                                 BRCA  ...            205.0
# 1                                 BRCA  ...            190.0
# 2                                 BRCA  ...            365.0
# 3                                 BRCA  ...             25.0
# 4                                 BRCA  ...             36.0
#
#    Tissue Prospective Collection Indicator  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                      Yes
#
#    Tissue Retrospective Collection Indicator   Tissue Source Site  \
# 0                                        Yes  Columbia University
# 1                                        Yes  Columbia University
# 2                                        Yes  Columbia University
# 3                                        Yes  Columbia University
# 4                                         No    Proteogenex, Inc.
#
#    Tissue Source Site Code TMB (nonsynonymous)  Tumor Disease Anatomic Site  \
# 0                       3C            0.800000                       Breast
# 1                       3C           15.266667                       Breast
# 2                       3C            0.933333                       Breast
# 3                       3C            1.500000                       Breast
# 4                       4H            0.700000                       Breast
#
#                        Tumor Type Patient Weight Winter Hypoxia Score
# 0  Infiltrating Lobular Carcinoma            NaN                -28.0
# 1   Infiltrating Ductal Carcinoma            NaN                 20.0
# 2   Infiltrating Ductal Carcinoma            NaN                -10.0
# 3   Infiltrating Ductal Carcinoma            NaN                  4.0
# 4  Infiltrating Lobular Carcinoma            NaN                -20.0
#
# [5 rows x 63 columns]

# %%
# Get column information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084 entries, 0 to 1083
# Data columns (total 63 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   Study ID                                                                                     1084 non-null   object
#  1   Patient ID                                                                                   1084 non-null   object
#  2   Sample ID                                                                                    1084 non-null   object
#  3   Diagnosis Age                                                                                1084 non-null   int64
#  4   Neoplasm Disease Stage American Joint Committee on Cancer Code                               1079 non-null   object
#  5   American Joint Committee on Cancer Publication Version Type                                  944 non-null    object
#  6   Aneuploidy Score                                                                             1041 non-null   float64
#  7   Buffa Hypoxia Score                                                                          1079 non-null   float64
#  8   Cancer Type                                                                                  1084 non-null   object
#  9   TCGA PanCanAtlas Cancer Type Acronym                                                         1084 non-null   object
#  10  Cancer Type Detailed                                                                         1084 non-null   object
#  11  Last Communication Contact from Initial Pathologic Diagnosis Date                            980 non-null    float64
#  12  Birth from Initial Pathologic Diagnosis Date                                                 1069 non-null   float64
#  13  Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value                       1084 non-null   int64
#  14  Disease Free (Months)                                                                        941 non-null    float64
#  15  Disease Free Status                                                                          942 non-null    object
#  16  Months of disease-specific survival                                                          1082 non-null   float64
#  17  Disease-specific Survival status                                                             1064 non-null   object
#  18  Ethnicity Category                                                                           915 non-null    object
#  19  Form completion date                                                                         1084 non-null   object
#  20  Fraction Genome Altered                                                                      1068 non-null   float64
#  21  Genetic Ancestry Label                                                                       961 non-null    object
#  22  Neoplasm Histologic Grade                                                                    0 non-null      float64
#  23  Neoadjuvant Therapy Type Administered Prior To Resection Text                                1083 non-null   object
#  24  ICD-10 Classification                                                                        1084 non-null   object
#  25  International Classification of Diseases for Oncology, Third Edition ICD-O-3 Histology Code  1084 non-null   object
#  26  International Classification of Diseases for Oncology, Third Edition ICD-O-3 Site Code       1084 non-null   object
#  27  In PanCan Pathway Analysis                                                                   1084 non-null   object
#  28  Informed consent verified                                                                    1084 non-null   object
#  29  MSI MANTIS Score                                                                             1034 non-null   float64
#  30  MSIsensor Score                                                                              1075 non-null   float64
#  31  Mutation Count                                                                               1009 non-null   float64
#  32  New Neoplasm Event Post Initial Therapy Indicator                                            885 non-null    object
#  33  Oncotree Code                                                                                1084 non-null   object
#  34  Overall Survival (Months)                                                                    1084 non-null   float64
#  35  Overall Survival Status                                                                      1084 non-null   object
#  36  Other Patient ID                                                                             1084 non-null   object
#  37  American Joint Committee on Cancer Metastasis Stage Code                                     1084 non-null   object
#  38  Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code                    1084 non-null   object
#  39  American Joint Committee on Cancer Tumor Stage Code                                          1084 non-null   object
#  40  Person Neoplasm Cancer Status                                                                961 non-null    object
#  41  Progress Free Survival (Months)                                                              1082 non-null   float64
#  42  Progression Free Status                                                                      1083 non-null   object
#  43  Primary Lymph Node Presentation Assessment                                                   720 non-null    object
#  44  Prior Diagnosis                                                                              1083 non-null   object
#  45  Race Category                                                                                994 non-null    object
#  46  Radiation Therapy                                                                            983 non-null    object
#  47  Ragnum Hypoxia Score                                                                         1079 non-null   float64
#  48  Number of Samples Per Patient                                                                1084 non-null   int64
#  49  Sample Type                                                                                  1084 non-null   object
#  50  Sex                                                                                          1084 non-null   object
#  51  Somatic Status                                                                               1084 non-null   object
#  52  Subtype                                                                                      981 non-null    object
#  53  Tumor Break Load                                                                             1082 non-null   float64
#  54  Tissue Prospective Collection Indicator                                                      1080 non-null   object
#  55  Tissue Retrospective Collection Indicator                                                    1080 non-null   object
#  56  Tissue Source Site                                                                           1084 non-null   object
#  57  Tissue Source Site Code                                                                      1084 non-null   object
#  58  TMB (nonsynonymous)                                                                          1066 non-null   float64
#  59  Tumor Disease Anatomic Site                                                                  1084 non-null   object
#  60  Tumor Type                                                                                   1084 non-null   object
#  61  Patient Weight                                                                               0 non-null      float64
#  62  Winter Hypoxia Score                                                                         1079 non-null   float64
# dtypes: float64(18), int64(3), object(42)
# memory usage: 533.7+ KB

# %%
# Summary statistics
df.describe()
# Out:
#        Diagnosis Age  Aneuploidy Score  Buffa Hypoxia Score  \
# count    1084.000000       1041.000000          1079.000000
# mean       58.420664         12.122959           -10.078777
# std        13.219721          7.818510            21.567866
# min        26.000000          0.000000           -49.000000
# 25%        49.000000          5.000000           -27.000000
# 50%        58.000000         11.000000           -13.000000
# 75%        67.000000         19.000000             7.000000
# max        90.000000         35.000000            47.000000
#
#        Last Communication Contact from Initial Pathologic Diagnosis Date  \
# count                                         980.000000
# mean                                         1177.098980
# std                                          1179.076793
# min                                           -31.000000
# 25%                                           430.750000
# 50%                                           757.000000
# 75%                                          1547.250000
# max                                          8605.000000
#
#        Birth from Initial Pathologic Diagnosis Date  \
# count                                   1069.000000
# mean                                  -21572.204864
# std                                     4815.321503
# min                                   -32873.000000
# 25%                                   -24831.000000
# 50%                                   -21534.000000
# 75%                                   -18021.000000
# max                                    -9706.000000
#
#        Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value  \
# count                                             1084.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Disease Free (Months)  Months of disease-specific survival  \
# count             941.000000                          1082.000000
# mean               37.944970                            40.843702
# std                36.193906                            39.391553
# min                 0.000000                             0.000000
# 25%                14.268337                            14.703948
# 50%                24.986028                            27.007923
# 75%                50.958346                            55.002137
# max               281.290068                           282.901009
#
#        Fraction Genome Altered  Neoplasm Histologic Grade  ...  \
# count              1068.000000                        0.0  ...
# mean                  0.295378                        NaN  ...
# std                   0.206738                        NaN  ...
# min                   0.000000                        NaN  ...
# 25%                   0.126050                        NaN  ...
# 50%                   0.251150                        NaN  ...
# 75%                   0.436350                        NaN  ...
# max                   0.997100                        NaN  ...
#
#        MSIsensor Score  Mutation Count  Overall Survival (Months)  \
# count      1075.000000     1009.000000                1084.000000
# mean          0.519991       83.478692                  40.830613
# std           1.762630      283.199229                  39.357513
# min           0.000000        1.000000                   0.000000
# 25%           0.030000       26.000000                  14.720387
# 50%           0.190000       39.000000                  27.007923
# 75%           0.535000       68.000000                  55.002137
# max          32.920000     5400.000000                 282.901009
#
#        Progress Free Survival (Months)  Ragnum Hypoxia Score  \
# count                      1082.000000           1079.000000
# mean                         37.914820              2.526413
# std                          35.623008             12.410309
# min                           0.000000            -24.000000
# 25%                          14.087517             -8.000000
# 50%                          25.117533              4.000000
# 75%                          51.369300             14.000000
# max                         281.290068             30.000000
#
#        Number of Samples Per Patient  Tumor Break Load  TMB (nonsynonymous)  \
# count                         1084.0       1082.000000          1066.000000
# mean                             1.0        132.835952             2.734271
# std                              0.0        183.792046             9.287938
# min                              1.0          0.000000             0.000000
# 25%                              1.0         26.000000             0.833333
# 50%                              1.0         82.500000             1.300000
# 75%                              1.0        190.000000             2.300000
# max                              1.0       3662.000000           180.833333
#
#        Patient Weight  Winter Hypoxia Score
# count             0.0           1079.000000
# mean              NaN            -11.471733
# std               NaN             21.017858
# min               NaN            -72.000000
# 25%               NaN            -28.000000
# 50%               NaN            -14.000000
# 75%               NaN              2.000000
# max               NaN             78.000000
#
# [8 rows x 21 columns]

# %%
# Check for missing values
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# Neoplasm Disease Stage American Joint Committee on Cancer Code          5
# American Joint Committee on Cancer Publication Version Type           140
# Aneuploidy Score                                                       43
# Buffa Hypoxia Score                                                     5
# Last Communication Contact from Initial Pathologic Diagnosis Date     104
# Birth from Initial Pathologic Diagnosis Date                           15
# Disease Free (Months)                                                 143
# Disease Free Status                                                   142
# Months of disease-specific survival                                     2
# Disease-specific Survival status                                       20
# Ethnicity Category                                                    169
# Fraction Genome Altered                                                16
# Genetic Ancestry Label                                                123
# Neoplasm Histologic Grade                                            1084
# Neoadjuvant Therapy Type Administered Prior To Resection Text           1
# MSI MANTIS Score                                                       50
# MSIsensor Score                                                         9
# Mutation Count                                                         75
# New Neoplasm Event Post Initial Therapy Indicator                     199
# Person Neoplasm Cancer Status                                         123
# Progress Free Survival (Months)                                         2
# Progression Free Status                                                 1
# Primary Lymph Node Presentation Assessment                            364
# Prior Diagnosis                                                         1
# Race Category                                                          90
# Radiation Therapy                                                     101
# Ragnum Hypoxia Score                                                    5
# Subtype                                                               103
# Tumor Break Load                                                        2
# Tissue Prospective Collection Indicator                                 4
# Tissue Retrospective Collection Indicator                               4
# TMB (nonsynonymous)                                                    18
# Patient Weight                                                       1084
# Winter Hypoxia Score                                                    5
# dtype: int64

# %%
df["Race Category"].value_counts()
# Out:
# Race Category
# White                               751
# Black or African American           182
# Asian                                60
# American Indian or Alaska Native      1
# Name: count, dtype: int64

# %% [markdown]
# ## Data Preparation

# %%
# Set the appropriate column names based on your data exploration
# UPDATE THESE BASED ON YOUR ACTUAL COLUMN NAMES
race_column = "Race Category"  # Replace with actual column name
time_column = "Overall Survival (Months)"  # Replace with actual column name
event_column = "Overall Survival Status"  # Replace with actual column name (1=event occurred, 0=censored)

# %%
# Prepare data for survival analysis
def prepare_survival_data(df, race_column, time_column, event_column):
    """Prepare data for survival analysis"""
    # Make a copy to avoid modifying the original dataframe
    survival_df = df.copy()

    # Handle missing values
    survival_df = survival_df.dropna(subset=[race_column, time_column, event_column])

    # Remove Native American patients due to small sample size
    survival_df[race_column] = survival_df[race_column].loc[
        survival_df[race_column].isin(["Black or African American", "White", "Asian"])
    ]

    # Create binary indicator for Black patients
    survival_df["is_black"] = (
        survival_df[race_column] == "Black or African American"
    ).astype(int)

    # Survival status: 1 for event occurred, 0 for censored
    survival_df["event"] = survival_df[event_column].apply(
        lambda x: 1 if x == "1:DECEASED" else 0
    )

    return survival_df


# Create the survival dataframe
survival_df = prepare_survival_data(df, race_column, time_column, event_column)
event_column = "event"
survival_df.head()
# Out:
#                        Study ID    Patient ID        Sample ID  Diagnosis Age  \
# 0  brca_tcga_pan_can_atlas_2018  TCGA-3C-AAAU  TCGA-3C-AAAU-01             55
# 1  brca_tcga_pan_can_atlas_2018  TCGA-3C-AALI  TCGA-3C-AALI-01             50
# 2  brca_tcga_pan_can_atlas_2018  TCGA-3C-AALJ  TCGA-3C-AALJ-01             62
# 3  brca_tcga_pan_can_atlas_2018  TCGA-3C-AALK  TCGA-3C-AALK-01             52
# 4  brca_tcga_pan_can_atlas_2018  TCGA-4H-AAAK  TCGA-4H-AAAK-01             50
#
#   Neoplasm Disease Stage American Joint Committee on Cancer Code  \
# 0                                            STAGE X
# 1                                          STAGE IIB
# 2                                          STAGE IIB
# 3                                           STAGE IA
# 4                                         STAGE IIIA
#
#   American Joint Committee on Cancer Publication Version Type  \
# 0                                                6TH
# 1                                                6TH
# 2                                                7TH
# 3                                                7TH
# 4                                                7TH
#
#    Aneuploidy Score  Buffa Hypoxia Score    Cancer Type  \
# 0              19.0                -21.0  Breast Cancer
# 1              22.0                  5.0  Breast Cancer
# 2              13.0                 -5.0  Breast Cancer
# 3               4.0                -27.0  Breast Cancer
# 4               7.0                -27.0  Breast Cancer
#
#   TCGA PanCanAtlas Cancer Type Acronym  ...  \
# 0                                 BRCA  ...
# 1                                 BRCA  ...
# 2                                 BRCA  ...
# 3                                 BRCA  ...
# 4                                 BRCA  ...
#
#   Tissue Retrospective Collection Indicator   Tissue Source Site  \
# 0                                       Yes  Columbia University
# 1                                       Yes  Columbia University
# 2                                       Yes  Columbia University
# 3                                       Yes  Columbia University
# 4                                        No    Proteogenex, Inc.
#
#    Tissue Source Site Code  TMB (nonsynonymous)  Tumor Disease Anatomic Site  \
# 0                       3C             0.800000                       Breast
# 1                       3C            15.266667                       Breast
# 2                       3C             0.933333                       Breast
# 3                       3C             1.500000                       Breast
# 4                       4H             0.700000                       Breast
#
#                        Tumor Type  Patient Weight Winter Hypoxia Score  \
# 0  Infiltrating Lobular Carcinoma             NaN                -28.0
# 1   Infiltrating Ductal Carcinoma             NaN                 20.0
# 2   Infiltrating Ductal Carcinoma             NaN                -10.0
# 3   Infiltrating Ductal Carcinoma             NaN                  4.0
# 4  Infiltrating Lobular Carcinoma             NaN                -20.0
#
#   is_black event
# 0        0     0
# 1        1     0
# 2        1     0
# 3        1     0
# 4        0     0
#
# [5 rows x 65 columns]

# %%
# Plot the race distribution
plt.figure(figsize=(10, 6))

# Drop rows with missing values in the "Race Category" column
race_counts = survival_df["Race Category"].dropna().value_counts()

# Create the bar plot
plt.bar(race_counts.index, race_counts.values, color="")
plt.title("Race Distribution in the Dataset", fontsize=14)
plt.xlabel("Race Category", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis="y", alpha=0.3)
plt.show()

# %%
# Plot the distribution of cancer stages
# Group cancer stages by number
stage_mapping = {
    "STAGE I": "Stage 1",
    "STAGE IA": "Stage 1",
    "STAGE IB": "Stage 1",
    "STAGE II": "Stage 2",
    "STAGE IIA": "Stage 2",
    "STAGE IIB": "Stage 2",
    "STAGE III": "Stage 3",
    "STAGE IIIA": "Stage 3",
    "STAGE IIIB": "Stage 3",
    "STAGE IIIC": "Stage 3",
    "STAGE IV": "Stage 4",
    "STAGE X": "Unknown",
}

# Apply the mapping to create a new column for grouped stages
survival_df["Grouped Stage"] = (
    survival_df["Neoplasm Disease Stage American Joint Committee on Cancer Code"]
    .dropna()
    .map(stage_mapping)
)

plt.figure(figsize=(10, 6))

# Drop rows with missing values in the "Neoplasm Disease Stage American Joint Committee on Cancer Code" column
stage_counts = survival_df["Grouped Stage"].dropna().value_counts()

# Create the bar plot
# Order the stages for the bar plot
ordered_stages = ["Stage 1", "Stage 2", "Stage 3", "Stage 4", "Unknown"]
stage_counts = stage_counts.reindex(ordered_stages)

plt.bar(
    stage_counts.index,
    stage_counts.values,
)
plt.title("Distribution of Cancer Stages", fontsize=14)
plt.xlabel("Cancer Stage", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis="y", alpha=0.3)
plt.show()

# %% [markdown]
# ## Exploratory Data Visualization
#
# Let's create some visualizations to better understand the data.

# %%
# Uncomment and run after confirming column names

# Distribution of survival time by race
ordered_stages = ["Stage 1", "Stage 2", "Stage 3", "Stage 4", "Unknown"]
stage_counts = stage_counts.reindex(ordered_stages)

plt.figure(figsize=(10, 6))
sns.boxplot(x=race_column, y=time_column, data=survival_df)
plt.title("Distribution of Survival Time by Race", fontsize=14)
plt.xlabel("Race", fontsize=12)
plt.ylabel("Survival Time (months)", fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Calculate average survival times grouped by race
average_survival_by_race = survival_df.groupby(race_column)[time_column].mean()

# Display the result
print(average_survival_by_race)
# Out:
# Race Category
# Asian                        22.737285
# Black or African American    42.015554
# White                        44.282935
# Name: Overall Survival (Months), dtype: float64

# %%
from scipy.stats import ttest_ind

# Filter data for Black and White patients
black_patients = survival_df[survival_df[race_column] == "Black or African American"]
white_patients = survival_df[survival_df[race_column] == "White"]

# Perform the two-sample t-test
t_stat, p_value = ttest_ind(
    black_patients[time_column].dropna(),
    white_patients[time_column].dropna(),
    equal_var=False,  # Welch's t-test
)

# Print the results
print("Two-sample t-test results:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print(
        "There is a statistically significant difference in average survival time between Black and White patients."
    )
else:
    print(
        "There is no statistically significant difference in average survival time between Black and White patients."
    )
# Out:
# Two-sample t-test results:
# T-statistic: -0.6640
# P-value: 0.5072
# There is no statistically significant difference in average survival time between Black and White patients.

# %%
# Replace "Survival Status" with the correct column name, e.g., "event"
survival_df["Overall Survival Status"].value_counts()
# Out:
# Overall Survival Status
# 0:LIVING      850
# 1:DECEASED    144
# Name: count, dtype: int64

# %%
# Uncomment and run after confirming column names

survival_df["Survival Status"] = survival_df[event_column].apply(
    lambda x: "Deceased" if x == 1 else "Living"
)
# Move the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", fontsize=10)
# Adjust the legend position to avoid overlap with the bars
event_by_race = pd.crosstab(
    survival_df[race_column], survival_df["Survival Status"], normalize="index"
).sort_index(ascending=False)
event_by_race.plot(
    kind="bar", stacked=True, colormap="viridis", figsize=(10, 6)
).legend(bbox_to_anchor=(1.05, 1), loc="upper left", fontsize=10)
plt.title("Survival Rate by Race", fontsize=14)
plt.xlabel("Race", fontsize=12)
plt.ylabel("Proportion", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.savefig("survival_prop", bbox_inches="tight")
plt.show()

# %%
# Display the proportions of event rates by race
print(event_by_race)
# Out:
# event                             0         1
# Race Category
# Asian                      0.950000  0.050000
# Black or African American  0.835165  0.164835
# White                      0.852197  0.147803

# %%
# Create a contingency table for survival proportions
contingency_table = pd.crosstab(survival_df["is_black"], survival_df[event_column])

# Perform the chi-squared test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-squared test results:")
print(f"Chi-squared statistic: {chi2:.4f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

if p < 0.05:
    print(
        "There is a statistically significant difference in survival proportions between Black and White patients."
    )
else:
    print(
        "There is no statistically significant difference in survival proportions between Black and White patients."
    )
# Out:
# Chi-squared test results:
# Chi-squared statistic: 0.5332
# P-value: 0.4653
# Degrees of freedom: 1
# Expected frequencies:
# [[694.36619718 117.63380282]
#  [155.63380282  26.36619718]]
# There is no statistically significant difference in survival proportions between Black and White patients.

# %% [markdown]
# ## Kaplan-Meier Survival Analysis
#
# Now we'll perform a Kaplan-Meier survival analysis to compare Black patients to others.

# %%
# Uncomment and run after confirming column names

# Kaplan-Meier survival analysis


def kaplan_meier_analysis(df, time_column, event_column, group_column="is_black"):
    """Perform Kaplan-Meier survival analysis comparing Black patients to others"""
    kmf = KaplanMeierFitter()

    # Create survival plot
    plt.figure(figsize=(12, 8))

    # Plot survival curve for Black patients
    black_mask = df[group_column] == 1
    kmf.fit(
        df[black_mask][time_column],
        df[black_mask][event_column],
        label="Black patients",
    )
    ax = kmf.plot(ci_show=True)

    # Plot survival curve for other patients
    other_mask = df[group_column] == 0
    kmf.fit(
        df[other_mask][time_column],
        df[other_mask][event_column],
        label="Other patients",
    )
    kmf.plot(ax=ax, ci_show=True)

    plt.title("Kaplan-Meier Survival Curves by Race", fontsize=16)
    plt.xlabel("Time (months)", fontsize=14)
    plt.ylabel("Survival Probability", fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True)
    plt.show()

    # Perform log-rank test to compare survival curves
    results = logrank_test(
        df[black_mask][time_column],
        df[other_mask][time_column],
        df[black_mask][event_column],
        df[other_mask][event_column],
    )

    print("\n--- Log-rank Test Results ---")
    print(f"Test statistic: {results.test_statistic:.4f}")
    print(f"p-value: {results.p_value:.4f}")
    if results.p_value < 0.05:
        print(
            "There is a statistically significant difference in survival between Black patients and others."
        )
    else:
        print(
            "There is no statistically significant difference in survival between Black patients and others."
        )

    return results


# Run the Kaplan-Meier analysis
logrank_results = kaplan_meier_analysis(survival_df, time_column, event_column)
# Out:
# --- Log-rank Test Results ---
# Test statistic: 0.9484
# p-value: 0.3301
# There is no statistically significant difference in survival between Black patients and others.

# %% [markdown]
# ## Cox Proportional Hazards Regression
#
# Next, we'll perform a Cox regression to adjust for other covariates that might influence survival.

# %%
# Uncomment and run after confirming covariates

# Cox Proportional Hazards Regression


def cox_regression_analysis(
    df, time_column, event_column, group_column="is_black", covariates=None
):
    """Perform Cox Proportional Hazards regression analysis"""
    cph = CoxPHFitter()

    # Prepare data for Cox regression
    if covariates is None:
        # If no covariates specified, just use race
        covariates = [group_column]
    else:
        # Add race to covariates if not already included
        if group_column not in covariates:
            covariates = [group_column] + covariates

    # Fit the Cox model
    cph.fit(
        df[covariates + [time_column, event_column]],
        duration_col=time_column,
        event_col=event_column,
    )

    # Print results
    print("\n--- Cox Proportional Hazards Model Results ---")
    display(cph.summary)

    # Plot hazard ratios
    plt.figure(figsize=(12, 8))
    cph.plot()
    plt.title("Hazard Ratios with 95% Confidence Intervals", fontsize=16)
    plt.grid(True)
    plt.show()

    return cph


# Run Cox regression
cph_model = cox_regression_analysis(
    survival_df, time_column, event_column, covariates=available_covariates
)
# Out:
# --- Cox Proportional Hazards Model Results ---
#                coef  exp(coef)  se(coef)  coef lower 95%  coef upper 95%  \
# covariate
# is_black   0.199765   1.221116  0.205347       -0.202707        0.602237
#
#            exp(coef) lower 95%  exp(coef) upper 95%  cmp to         z  \
# covariate
# is_black              0.816517               1.8262     0.0  0.972819
#
#                   p  -log2(p)
# covariate
# is_black   0.330643  1.596652
